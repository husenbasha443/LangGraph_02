# %% [markdown]
# #### Craete a Custom Exception

# %% [markdown]
# ###### Craete a Excetion Class

# %%
class InvalidAgeError:
    pass

# %%
age = int(input("Enter a Age"))
try:
    if age<18:
        raise InvalidAgeError("Not Eligible for Voting")
    print("He is a Eligible for Voting")
except Exception as ex:
    print(ex)
# Out:
# InvalidAgeError() takes no arguments
