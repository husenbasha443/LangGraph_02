# %%
class InvalidUserNameException(Exception):
    pass

# %%
username = "admin"
try:
    if username == "admins":
        raise InvalidUserNameException("You Have Enteres a Invalid Username")
    else:
        print("UserName is Valiadted")
except InvalidUserNameException as ex:
    print("Username is handles")
# Out:
# UserName is Valiadted
