

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1044 non-null   object
#  1   link             1044 non-null   object
#  2   society          453 non-null    object
#  3   price            968 non-null    object
#  4   rate             1005 non-null   object
#  5   area             1044 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
# ...

# %% [markdown]
# df.head()

# %% [markdown]
# #### To print first 5 records

# %%
df.head()
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  Bptp Visionnaire
# 1  https://www.99acres.com/5-bhk-bedroom-independ...               NaN
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...               NaN
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...               NaN
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# ...

# %% [markdown]
# #### To print the last 5 records

# %%
df.tail()
# Out:
#                                       property_name  \
# 1039  4 Bedroom House for sale in Sector 26 Gurgaon
# 1040        3 Bedroom House for sale in DLF Phase 2
# 1041  3 Bedroom House for sale in Sector 26 Gurgaon
# 1042  3 Bedroom House for sale in Sector 26 Gurgaon
# 1043             3 Bedroom House for sale in Bissar
#
#                                                    link  \
# 1039  https://www.99acres.com/4-bhk-bedroom-independ...
# 1040  https://www.99acres.com/3-bhk-bedroom-independ...
# 1041  https://www.99acres.com/3-bhk-bedroom-independ...
# 1042  https://www.99acres.com/3-bhk-bedroom-independ...
# 1043  https://www.99acres.com/3-bhk-bedroom-independ...
#
#                                        society       price             rate  \
# 1039                          DLF City Phase 1   5.5 Crore  ₹ 30,556/sq.ft.
# 1040                    DLF City Plots Phase 2  4.25 Crore  ₹ 31,481/sq.ft.
# 1041                          DLF City Phase 1   4.5 Crore  ₹ 33,333/sq.ft.
# ...

# %%
print(df.describe())
# Out:
#                                          property_name  \
# count                                             1044
# unique                                             559
# top     4 Bedroom House for sale in Sector 109 Gurgaon
# freq                                                25
#
#                                                      link             society  \
# count                                                1044                 453
# unique                                               1031                 185
# top     https://www.99acres.com/4-bhk-bedroom-independ...  Emaar MGF Marbella
# freq                                                    2                  26
#
#             price             rate                   area  \
# count         968             1005                   1044
# unique        302              752                    379
# top     3.5 Crore  ₹ 22,222/sq.ft.  (301 sq.m.) Plot Area
# freq           19               14                     44
#
# ...

# %% [markdown]
# #### Using loc() and iloc functions

# %%
print(df.loc[:900])
# Out:
#                                          property_name  \
# 0       5 Bedroom House for sale in Sector 70A Gurgaon
# 1     5 Bedroom House for sale in Sector 21A Faridabad
# 2     10 Bedroom House for sale in Sushant Lok Phase 1
# 3       21 Bedroom House for sale in Sector 54 Gurgaon
# 4     12 Bedroom House for sale in Sushant Lok Phase 1
# ..                                                 ...
# 896     3 Bedroom House for sale in Sector 70A Gurgaon
# 897  5 Bedroom House for sale in A Block Sushant Lo...
# 898      5 Bedroom House for sale in Sector 39 Gurgaon
# 899     3 Bedroom House for sale in Sector 70A Gurgaon
# 900     2 Bedroom House for sale in Sector 70A Gurgaon
#
#                                                   link  \
# 0    https://www.99acres.com/5-bhk-bedroom-independ...
# 1    https://www.99acres.com/5-bhk-bedroom-independ...
# 2    https://www.99acres.com/10-bhk-bedroom-indepen...
# 3    https://www.99acres.com/21-bhk-bedroom-indepen...
# ...

# %%
df['price']
# Out:
# 0       5.25 Crore
# 1        5.7 Crore
# 2        2.1 Crore
# 3          5 Crore
# 4          3 Crore
#            ...
# 1039     5.5 Crore
# 1040    4.25 Crore
# 1041     4.5 Crore
# 1042    3.25 Crore
# 1043     3.6 Crore
# Name: price, Length: 1044, dtype: object

# %% [markdown]
# #### Print the Number of Rows and Coloumns `

# %%
df.shape
# Out:
# (1044, 21)

# %% [markdown]
# #### Print all column names.

# %%
df.columns
# Out:
# Index(['property_name', 'link', 'society', 'price', 'rate', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'additionalRoom',
#        'address', 'noOfFloor', 'facing', 'agePossession', 'nearbyLocations',
#        'description', 'furnishDetails', 'features', 'rating', 'property_id'],
#       dtype='object')

# %% [markdown]
# #### Check the data types of each column.

# %%
df.dtypes
# Out:
# property_name      object
# link               object
# society            object
# price              object
# rate               object
# area               object
# areaWithType       object
# bedRoom            object
# bathroom           object
# balcony            object
# additionalRoom     object
# address            object
# noOfFloor          object
# facing             object
# agePossession      object
# nearbyLocations    object
# description        object
# furnishDetails     object
# features           object
# rating             object
# property_id        object
# dtype: object

# %% [markdown]
# #### Generate summary statistics using describe().

# %%
df.describe()
# Out:
#                                          property_name  \
# count                                             1044
# unique                                             559
# top     4 Bedroom House for sale in Sector 109 Gurgaon
# freq                                                25
#
#                                                      link             society  \
# count                                                1044                 453
# unique                                               1031                 185
# top     https://www.99acres.com/4-bhk-bedroom-independ...  Emaar MGF Marbella
# freq                                                    2                  26
#
#             price             rate                   area  \
# count         968             1005                   1044
# unique        302              752                    379
# top     3.5 Crore  ₹ 22,222/sq.ft.  (301 sq.m.) Plot Area
# freq           19               14                     44
#
# ...

# %% [markdown]
# #### Select only one column (e.g., price).`

# %%
df[['additionalRoom',"area",'price']]
# Out:
#                                  additionalRoom                   area  \
# 0                                  Servant Room  (242 sq.m.) Plot Area
# 1            Store Room,Pooja Room,Servant Room   (50 sq.m.) Plot Area
# 2                                  Servant Room   (51 sq.m.) Plot Area
# 3                                  Servant Room  (108 sq.m.) Plot Area
# 4                                        Others   (52 sq.m.) Plot Area
# ...                                         ...                    ...
# 1039         Pooja Room,Study Room,Servant Room  (167 sq.m.) Plot Area
# 1040                                 Study Room  (125 sq.m.) Plot Area
# 1041                    Study Room,Servant Room  (125 sq.m.) Plot Area
# 1042                                 Study Room   (91 sq.m.) Plot Area
# 1043  Pooja Room,Study Room,Servant Room,Others  (226 sq.m.) Plot Area
#
#            price
# 0     5.25 Crore
# 1      5.7 Crore
# 2      2.1 Crore
# 3        5 Crore
# 4        3 Crore
# ...
